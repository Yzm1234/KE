# %% [markdown]
# ## This notebook does feature normalization, scale all feature values to range [0, 1]

# %%
import pandas as pd
import os
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ### Set file path

# %%
## add data path
data_dir = "/global/homes/z/zimingy/KE-Catboost/ziming/GO/data/go_aggregated_4.1"

data_file = os.path.join(data_dir, 'go_aggregated_4.1_mixed_updated.pkl')
output_pickle = os.path.join(data_dir, 'go_aggregated_4.1_mixed_updated_normalized.pkl')
output_tsv = os.path.join(data_dir, 'go_aggregated_4.1_mixed_updated_normalized.tsv')

# %% [markdown]
# ### Load original dataset

# %%
# %%time
df = pd.read_pickle(data_file)
null_vals = df.isnull().sum(axis=0)
assert len(null_vals[null_vals != 0]) == 0
df
# Out:
# CPU times: user 589 ms, sys: 1.34 s, total: 1.93 s
# Wall time: 2.06 s
#                id      study_id   sample_id  \
# 19      ERZ650344  MGYS00003358  SRS3210273
# 27      ERZ747221  MGYS00004737  SRS1791943
# 29      ERZ761615  MGYS00003390  SRS1984850
# 30     ERR2193276  MGYS00005065  ERS2001073
# 31     ERR2193277  MGYS00005065  ERS2001074
# ...           ...           ...         ...
# 73785   ERZ807429  MGYS00005443  ERS1960449
# 74255   ERZ795020  MGYS00004901   SRS785549
# 74256   ERZ505245  MGYS00003223  SRS1589217
# 74261   ERZ505291  MGYS00003237  SRS1589396
# 74262   ERZ777305  MGYS00004754   DRS013068
#
#                                                   biome      exptype version  \
# 19           root:Environmental:Aquatic:Marine:Brackish     assembly     4.1
# 27                         root:Engineered:Biogas plant     assembly     4.1
# 29                           root:Engineered:Bioreactor     assembly     4.1
# 30                         root:Host-associated:Mammals  metagenomic     4.1
# 31                         root:Host-associated:Mammals  metagenomic     4.1
# ...                                                 ...          ...     ...
# 73785  root:Host-associated:Human:Digestive system:Oral     assembly     4.1
# 74255                        root:Engineered:Wastewater     assembly     4.1
# 74256                 root:Environmental:Aquatic:Marine     assembly     4.1
# 74261                 root:Environmental:Aquatic:Marine     assembly     4.1
# 74262   root:Host-associated:Mammals:Respiratory system     assembly     4.1
#
#        GO:0043130  GO:0055074  GO:0055117  GO:0046933  ...  GO:0019357  \
# 19              3           0           0         342  ...           2
# 27             49           0           0         450  ...           2
# 29              2           0           0         270  ...          33
# 30              0           0           0          26  ...           0
# 31              0           0           0          31  ...           0
# ...           ...         ...         ...         ...  ...         ...
# 73785           0           0           0           3  ...           0
# 74255           0           0           0         115  ...           1
# 74256           1           0           0         336  ...           3
# 74261           2           0           0         299  ...           2
# 74262           0           0           0         323  ...          21
#
#        GO:0006527  GO:0004114  GO:0046423  GO:0034194  GO:0032183  GO:0007618  \
# 19             79          90           0          20           0           0
# 27            110           0           0          15           0           0
# 29            102           2           0          43           0           0
# 30             12           1           0          15           0           0
# 31             13           1           0          20           0           0
# ...           ...         ...         ...         ...         ...         ...
# 73785           0           0           0           0           0           0
# 74255          10           0           0           1           0           0
# 74256          54           1           0           7           0           0
# 74261          58           0           0          11           0           0
# 74262          41           1           0           0           0           0
#
#        GO:0030097  GO:0004520  GO:0033739
# 19              0          87          38
# 27              0         204          34
# 29              0          93          49
# 30              0           8           5
# 31              0          10           8
# ...           ...         ...         ...
# 73785           0           0           1
# 74255           0          41           8
# 74256           0          88          56
# 74261           0          74          53
# 74262           0         107          39
#
# [31939 rows x 4408 columns]

# %%
# %%time 
## Using pandas df directly will generate NaN values
## ~33min 43s
# scaler = MinMaxScaler()
# cols = df.columns[6:]
# df[cols] = pd.DataFrame(scaler.fit_transform(df[cols]), columns=cols)
# df

# %% [markdown]
# ### Normalization(Scaling)

# %%
## extract numerical values from df
x = df[df.columns[6:]].values
x
# Out:
# array([[  3,   0,   0, ...,   0,  87,  38],
#        [ 49,   0,   0, ...,   0, 204,  34],
#        [  2,   0,   0, ...,   0,  93,  49],
#        ...,
#        [  1,   0,   0, ...,   0,  88,  56],
#        [  2,   0,   0, ...,   0,  74,  53],
#        [  0,   0,   0, ...,   0, 107,  39]])

# %%
## check the maximum value, min value is 0
x.max()
# Out:
# 15834150

# %%
## Scale x using MinMaxScaler()
x_scaled =  MinMaxScaler().fit_transform(x)
x_scaled
# Out:
# array([[0.0012837 , 0.        , 0.        , ..., 0.        , 0.00393665,
#         0.00355439],
#        [0.02096705, 0.        , 0.        , ..., 0.        , 0.00923077,
#         0.00318025],
#        [0.0008558 , 0.        , 0.        , ..., 0.        , 0.00420814,
#         0.00458329],
#        ...,
#        [0.0004279 , 0.        , 0.        , ..., 0.        , 0.0039819 ,
#         0.00523805],
#        [0.0008558 , 0.        , 0.        , ..., 0.        , 0.00334842,
#         0.00495744],
#        [0.        , 0.        , 0.        , ..., 0.        , 0.00484163,
#         0.00364793]])

# %%
x_scaled.shape
# Out:
# (31939, 4402)

# %%
## check max value again
x_scaled.max()
# Out:
# 1.0

# %%
## update df numerical field with scaled values
df[df.columns[6:]] = x_scaled
df
# Out:
#                id      study_id   sample_id  \
# 19      ERZ650344  MGYS00003358  SRS3210273
# 27      ERZ747221  MGYS00004737  SRS1791943
# 29      ERZ761615  MGYS00003390  SRS1984850
# 30     ERR2193276  MGYS00005065  ERS2001073
# 31     ERR2193277  MGYS00005065  ERS2001074
# ...           ...           ...         ...
# 73785   ERZ807429  MGYS00005443  ERS1960449
# 74255   ERZ795020  MGYS00004901   SRS785549
# 74256   ERZ505245  MGYS00003223  SRS1589217
# 74261   ERZ505291  MGYS00003237  SRS1589396
# 74262   ERZ777305  MGYS00004754   DRS013068
#
#                                                   biome      exptype version  \
# 19           root:Environmental:Aquatic:Marine:Brackish     assembly     4.1
# 27                         root:Engineered:Biogas plant     assembly     4.1
# 29                           root:Engineered:Bioreactor     assembly     4.1
# 30                         root:Host-associated:Mammals  metagenomic     4.1
# 31                         root:Host-associated:Mammals  metagenomic     4.1
# ...                                                 ...          ...     ...
# 73785  root:Host-associated:Human:Digestive system:Oral     assembly     4.1
# 74255                        root:Engineered:Wastewater     assembly     4.1
# 74256                 root:Environmental:Aquatic:Marine     assembly     4.1
# 74261                 root:Environmental:Aquatic:Marine     assembly     4.1
# 74262   root:Host-associated:Mammals:Respiratory system     assembly     4.1
#
#        GO:0043130  GO:0055074  GO:0055117  GO:0046933  ...  GO:0019357  \
# 19       0.001284         0.0         0.0    0.001645  ...    0.037736
# 27       0.020967         0.0         0.0    0.002165  ...    0.037736
# 29       0.000856         0.0         0.0    0.001299  ...    0.622642
# 30       0.000000         0.0         0.0    0.000125  ...    0.000000
# 31       0.000000         0.0         0.0    0.000149  ...    0.000000
# ...           ...         ...         ...         ...  ...         ...
# 73785    0.000000         0.0         0.0    0.000014  ...    0.000000
# 74255    0.000000         0.0         0.0    0.000553  ...    0.018868
# 74256    0.000428         0.0         0.0    0.001617  ...    0.056604
# 74261    0.000856         0.0         0.0    0.001439  ...    0.037736
# 74262    0.000000         0.0         0.0    0.001554  ...    0.396226
#
#        GO:0006527  GO:0004114  GO:0046423  GO:0034194  GO:0032183  GO:0007618  \
# 19       0.002090    0.008326         0.0    0.000443         0.0         0.0
# 27       0.002910    0.000000         0.0    0.000332         0.0         0.0
# 29       0.002699    0.000185         0.0    0.000952         0.0         0.0
# 30       0.000318    0.000093         0.0    0.000332         0.0         0.0
# 31       0.000344    0.000093         0.0    0.000443         0.0         0.0
# ...           ...         ...         ...         ...         ...         ...
# 73785    0.000000    0.000000         0.0    0.000000         0.0         0.0
# 74255    0.000265    0.000000         0.0    0.000022         0.0         0.0
# 74256    0.001429    0.000093         0.0    0.000155         0.0         0.0
# 74261    0.001535    0.000000         0.0    0.000244         0.0         0.0
# 74262    0.001085    0.000093         0.0    0.000000         0.0         0.0
#
#        GO:0030097  GO:0004520  GO:0033739
# 19            0.0    0.003937    0.003554
# 27            0.0    0.009231    0.003180
# 29            0.0    0.004208    0.004583
# 30            0.0    0.000362    0.000468
# 31            0.0    0.000452    0.000748
# ...           ...         ...         ...
# 73785         0.0    0.000000    0.000094
# 74255         0.0    0.001855    0.000748
# 74256         0.0    0.003982    0.005238
# 74261         0.0    0.003348    0.004957
# 74262         0.0    0.004842    0.003648
#
# [31939 rows x 4408 columns]

# %%
## save new df to file
df.to_pickle(output_pickle)
df.to_csv(output_tsv, sep="\t")
