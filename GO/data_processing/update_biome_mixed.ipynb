# %%
import csv
import pandas as pd
import os
import numpy as np

# %% [markdown]
# ### Set file path

# %%
## data file and directory path
data_dir = '/global/cfs/cdirs/kbase/KE-Catboost/ziming/GO/data/go_aggregated_4.1'
## input file
input_file_tsv = os.path.join(data_dir, 'go_aggregated_4.1.tsv')
input_file_pickle = os.path.join(data_dir, 'go_aggregated_4.1.pkl')
mixed_label_file = os.path.join(data_dir, 'MGnify_root_mixed_worksheet-Full.tsv')
## output file 
output_file_tsv = os.path.join(data_dir, 'go_aggregated_4.1_mixed_updated.tsv')
output_file_pickle = os.path.join(data_dir, 'go_aggregated_4.1_mixed_updated.pkl')

# %% [markdown]
# ### Load original dataset

# %%
# %%time
if os.path.exists(input_file_pickle):
    df = pd.read_pickle(input_file_pickle)
else:
    with open(input_file_tsv, 'r') as f:
        df = pd.read_csv(f, sep="\t")
        df.to_pickle(input_file_pickle)
df
# Out:
# CPU times: user 449 ms, sys: 1.27 s, total: 1.72 s
# Wall time: 1.86 s
#                id      study_id   sample_id  \
# 19      ERZ650344  MGYS00003358  SRS3210273
# 27      ERZ747221  MGYS00004737  SRS1791943
# 29      ERZ761615  MGYS00003390  SRS1984850
# 30     ERR2193276  MGYS00005065  ERS2001073
# 31     ERR2193277  MGYS00005065  ERS2001074
# ...           ...           ...         ...
# 73785   ERZ807429  MGYS00005443  ERS1960449
# 74255   ERZ795020  MGYS00004901   SRS785549
# 74256   ERZ505245  MGYS00003223  SRS1589217
# 74261   ERZ505291  MGYS00003237  SRS1589396
# 74262   ERZ777305  MGYS00004754   DRS013068
#
#                                                   biome      exptype version  \
# 19           root:Environmental:Aquatic:Marine:Brackish     assembly     4.1
# 27                         root:Engineered:Biogas plant     assembly     4.1
# 29                           root:Engineered:Bioreactor     assembly     4.1
# 30                         root:Host-associated:Mammals  metagenomic     4.1
# 31                         root:Host-associated:Mammals  metagenomic     4.1
# ...                                                 ...          ...     ...
# 73785  root:Host-associated:Human:Digestive system:Oral     assembly     4.1
# 74255                        root:Engineered:Wastewater     assembly     4.1
# 74256                 root:Environmental:Aquatic:Marine     assembly     4.1
# 74261                 root:Environmental:Aquatic:Marine     assembly     4.1
# 74262   root:Host-associated:Mammals:Respiratory system     assembly     4.1
#
#        GO:0043130  GO:0055074  GO:0055117  GO:0046933  ...  GO:0019357  \
# 19              3           0           0         342  ...           2
# 27             49           0           0         450  ...           2
# 29              2           0           0         270  ...          33
# 30              0           0           0          26  ...           0
# 31              0           0           0          31  ...           0
# ...           ...         ...         ...         ...  ...         ...
# 73785           0           0           0           3  ...           0
# 74255           0           0           0         115  ...           1
# 74256           1           0           0         336  ...           3
# 74261           2           0           0         299  ...           2
# 74262           0           0           0         323  ...          21
#
#        GO:0006527  GO:0004114  GO:0046423  GO:0034194  GO:0032183  GO:0007618  \
# 19             79          90           0          20           0           0
# 27            110           0           0          15           0           0
# 29            102           2           0          43           0           0
# 30             12           1           0          15           0           0
# 31             13           1           0          20           0           0
# ...           ...         ...         ...         ...         ...         ...
# 73785           0           0           0           0           0           0
# 74255          10           0           0           1           0           0
# 74256          54           1           0           7           0           0
# 74261          58           0           0          11           0           0
# 74262          41           1           0           0           0           0
#
#        GO:0030097  GO:0004520  GO:0033739
# 19              0          87          38
# 27              0         204          34
# 29              0          93          49
# 30              0           8           5
# 31              0          10           8
# ...           ...         ...         ...
# 73785           0           0           1
# 74255           0          41           8
# 74256           0          88          56
# 74261           0          74          53
# 74262           0         107          39
#
# [31939 rows x 4408 columns]

# %% [markdown]
# ### Load biomes mapping file

# %%
with open(mixed_label_file, 'r') as f:
    df_ = pd.read_csv(f, sep="\t")
    df_mixed_label = df_.where(pd.notnull(df_), 'Null')
df_mixed_label
# Out:
#                id   top-level    environment-biome environment-feature  \
# 0      ERS3792294  root:Mixed             Sediment            Sediment
# 1       SRS589645  root:Mixed                 Soil                Null
# 2       SRS589650  root:Mixed                 Soil                Null
# 3       SRS589658  root:Mixed                 Soil                Null
# 4       SRS589669  root:Mixed                plant                Null
# ...           ...         ...                  ...                 ...
# 17629  SRS3293561  root:Mixed                 Null                Null
# 17630  ERS2584481  root:Mixed  temperate grassland                soil
# 17631  ERS2468507  root:Mixed                 Null                Null
# 17632  SRS3293559  root:Mixed                 Null                Null
# 17633  ERS2584629  root:Mixed  temperate grassland                soil
#
#       environment-material
# 0                 Sediment
# 1                     Null
# 2                     Null
# 3                     Null
# 4                     Null
# ...                    ...
# 17629                 Null
# 17630          Caterpillar
# 17631                 Null
# 17632                 Null
# 17633                 Leaf
#
# [17634 rows x 5 columns]

# %% [markdown]
# ### Update biomes

# %%
## build a dictionary, sample id as key and biome as value
## filter out Null value biome 
mixed_label_dic = {}
for i, row in df_mixed_label.iterrows():
    labels_without_null = [i for i in row[1:] if i != 'Null']
    mixed_label_dic[row[0]] = ':'.join(labels_without_null)
mixed_label_dic
# Out:
# {'ERS3792294': 'root:Mixed:Sediment:Sediment:Sediment',
#  'SRS589645': 'root:Mixed:Soil',
#  'SRS589650': 'root:Mixed:Soil',
#  'SRS589658': 'root:Mixed:Soil',
#  'SRS589669': 'root:Mixed:plant',
#  'SRS589678': 'root:Mixed:plant',
#  'SRS589838': 'root:Mixed:Soil',
#  'SRS589840': 'root:Mixed:Soil',
#  'SRS589864': 'root:Mixed:Soil',
#  'ERS2304136': 'root:Mixed:urban biome:building:dust',
#  'ERS2301850': 'root:Mixed:village biome:human-associated habitat:sebum',
#  'ERS2301922': 'root:Mixed:village biome:animal-associated habitat:saliva',
#  'ERS2301672': 'root:Mixed:village biome:human-associated habitat:sebum',
#  'ERS2309271': 'root:Mixed:urban biome:building:dust',
#  'ERS2301533': 'root:Mixed:village biome:human-associated habitat:sebum',
#  'ERS2301555': 'root:Mixed:village biome:human-associated habitat:mucus',
#  'ERS2301556': 'root:Mixed:village biome:human-associated habitat:saliva',
#  'ERS2301557': 'root:Mixed:village biome:human-associated habitat:sebum',
#  'ERS2301558': 'root:Mixed:village biome:human-associated habitat:organic material',
#  'ERS2301559': 'root:Mixed:village biome:human-associated habitat:mucus',
#  'ERS2301560': 'root:Mixed:village biome:human-associated habitat:saliva',
#  'ERS2301755': 'root:Mixed:village biome:human-associated habitat:sebum',
#  'ERS2301764': 'root:Mixed:village biome:human-associated habitat:saliva',
#  'ERS2301766': 'root:Mixed:village biome:human-associated habitat:sebum',
#  'ERS2301768': 'root:Mixed:village biome:human-associated habitat:mucus',
#  'ERS2302104': 'root:Mixed:urban biome:human-associated habitat:sebum',
#  'ERS2302110': 'root:Mixed:urban biome:human-associated habitat:sebum',
#  'ERS2302112': 'root:Mixed:urban biome:human-associated habitat:saliva',
#  'ERS2302114': 'root:Mixed:urban biome:human-associated habitat:sebum',
#  'ERS2302117': 'root:Mixed:urban biome:human-associated habitat:saliva',
#  'ERS2302119': 'root:Mixed:urban biome:human-associated habitat:sebum',
#  'ERS2302130': 'root:Mixed:village biome:human-associated habitat:sebum',
#  'ERS2302204': 'root:Mixed:village biome:human-associated habitat:mucus',
#  'ERS2302293': 'root:Mixed:village biome:human-associated habitat:organic material',
#  'ERS2302296': 'root:Mixed:village biome:human-associated habitat:organic material',
#  'ERS2302302': 'root:Mixed:village biome:human-associated habitat:organic material',
#  'ERS2302305': 'root:Mixed:village biome:human-associated habitat:organic material',
#  'ERS2302308': 'root:Mixed:village biome:human-associated habitat:organic material',
#  'ERS2302311': 'root:Mixed:village biome:animal-associated habitat:organic material',
#  'ERS2302314': 'root:Mixed:village biome:animal-associated habitat:organic material',
#  'ERS2302318': 'root:Mixed:village biome:human-associated habitat:organic material',
#  'ERS2302321': 'root:Mixed:village biome:human-associated habitat:organic material',
#  'ERS2302325': 'root:Mixed:village biome:animal-associated habitat:organic material',
#  'ERS2302328': 'root:Mixed:village biome:human-associated habitat:organic material',
#  'ERS2302332': 'root:Mixed:village biome:human-associated habitat:organic material',
#  'ERS2302335': 'root:Mixed:village biome:human-associated habitat:organic material',
#  'ERS2302339': 'root:Mixed:urban biome:human-associated habitat:organic material',
#  'ERS2302342': 'root:Mixed:urban biome:human-associated habitat:organic material',
#  'ERS2302346': 'root:Mixed:urban biome:human-associated habitat:organic material',
#  'ERS2302349': 'root:Mixed:urban biome:human-associated habitat:organic material',
#  'ERS2468508': 'root:Mixed',
#  'SRS3293560': 'root:Mixed',
#  'ERS2584768': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS2468509': 'root:Mixed',
#  'SRS3293558': 'root:Mixed',
#  'ERS2584885': 'root:Mixed:temperate grassland:soil:Root',
#  'ERS2468510': 'root:Mixed',
#  'SRS3293556': 'root:Mixed',
#  'ERS2585090': 'root:Mixed:temperate grassland:soil:Soil',
#  'ERS2468511': 'root:Mixed',
#  'SRS3293557': 'root:Mixed',
#  'ERS2584343': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS2468512': 'root:Mixed',
#  'SRS3293555': 'root:Mixed',
#  'ERS2584482': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS2468513': 'root:Mixed',
#  'SRS3293554': 'root:Mixed',
#  'ERS2584630': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS2468514': 'root:Mixed',
#  'ERS2584769': 'root:Mixed:temperate grassland:soil:Leaf',
#  'SRS1846232': 'root:Mixed',
#  'ERS1376151': 'root:Mixed',
#  'ERS2468515': 'root:Mixed',
#  'ERS2584886': 'root:Mixed:temperate grassland:soil:Root',
#  'SRS1846233': 'root:Mixed',
#  'ERS1376152': 'root:Mixed',
#  'ERS2468516': 'root:Mixed',
#  'ERS2585067': 'root:Mixed:temperate grassland:soil:Soil',
#  'SRS1846236': 'root:Mixed',
#  'ERS1376153': 'root:Mixed',
#  'ERS2468517': 'root:Mixed',
#  'ERS1376154': 'root:Mixed',
#  'SRS1846234': 'root:Mixed',
#  'ERS2468518': 'root:Mixed',
#  'ERS2584344': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS1376155': 'root:Mixed',
#  'SRS1846235': 'root:Mixed',
#  'ERS2468519': 'root:Mixed',
#  'ERS2584483': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS1376156': 'root:Mixed',
#  'SRS1846237': 'root:Mixed',
#  'ERS2468520': 'root:Mixed',
#  'ERS2584770': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS1376157': 'root:Mixed',
#  'SRS1846238': 'root:Mixed',
#  'ERS2468521': 'root:Mixed',
#  'ERS2584887': 'root:Mixed:temperate grassland:soil:Root',
#  'ERS2468522': 'root:Mixed',
#  'ERS1376158': 'root:Mixed',
#  'SRS1846239': 'root:Mixed',
#  'ERS2585068': 'root:Mixed:temperate grassland:soil:Soil',
#  'ERS1376159': 'root:Mixed',
#  'SRS1846241': 'root:Mixed',
#  'ERS2468523': 'root:Mixed',
#  'ERS2585092': 'root:Mixed:temperate grassland:soil:Soil',
#  'ERS1376160': 'root:Mixed',
#  'ERS2468524': 'root:Mixed',
#  'SRS1846240': 'root:Mixed',
#  'ERS2584345': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS1376161': 'root:Mixed',
#  'ERS2468525': 'root:Mixed',
#  'SRS1846242': 'root:Mixed',
#  'ERS2584484': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS1376162': 'root:Mixed',
#  'SRS1846243': 'root:Mixed',
#  'ERS2468526': 'root:Mixed',
#  'ERS2584631': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS1376163': 'root:Mixed',
#  'SRS1846244': 'root:Mixed',
#  'ERS2468527': 'root:Mixed',
#  'ERS2584771': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS1376164': 'root:Mixed',
#  'SRS1846245': 'root:Mixed',
#  'ERS2468528': 'root:Mixed',
#  'ERS2584888': 'root:Mixed:temperate grassland:soil:Root',
#  'ERS1376165': 'root:Mixed',
#  'SRS1846246': 'root:Mixed',
#  'ERS2468529': 'root:Mixed',
#  'ERS2585069': 'root:Mixed:temperate grassland:soil:Soil',
#  'SRS1846247': 'root:Mixed',
#  'ERS1376166': 'root:Mixed',
#  'ERS2468530': 'root:Mixed',
#  'SRS1846248': 'root:Mixed',
#  'ERS2584346': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS1376167': 'root:Mixed',
#  'ERS2468531': 'root:Mixed',
#  'SRS1846249': 'root:Mixed',
#  'ERS2584485': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS1376168': 'root:Mixed',
#  'ERS2468532': 'root:Mixed',
#  'SRS1846251': 'root:Mixed',
#  'ERS2584632': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS1376169': 'root:Mixed',
#  'ERS2468533': 'root:Mixed',
#  'SRS1846250': 'root:Mixed',
#  'ERS1376170': 'root:Mixed',
#  'ERS2584772': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS2468534': 'root:Mixed',
#  'SRS1846252': 'root:Mixed',
#  'ERS2584889': 'root:Mixed:temperate grassland:soil:Root',
#  'ERS1376171': 'root:Mixed',
#  'SRS1846253': 'root:Mixed',
#  'ERS2468535': 'root:Mixed',
#  'ERS2585070': 'root:Mixed:temperate grassland:soil:Soil',
#  'ERS1376172': 'root:Mixed',
#  'SRS1846254': 'root:Mixed',
#  'ERS2468536': 'root:Mixed',
#  'ERS1376173': 'root:Mixed',
#  'SRS1846255': 'root:Mixed',
#  'ERS2584347': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS2468537': 'root:Mixed',
#  'ERS1376174': 'root:Mixed',
#  'SRS1846256': 'root:Mixed',
#  'ERS1376175': 'root:Mixed',
#  'ERS2584486': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS2468538': 'root:Mixed',
#  'SRS1846257': 'root:Mixed',
#  'ERS2584633': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS2468539': 'root:Mixed',
#  'ERS1376176': 'root:Mixed',
#  'SRS1846258': 'root:Mixed',
#  'ERS2584773': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS2468540': 'root:Mixed',
#  'ERS1376177': 'root:Mixed',
#  'SRS1846259': 'root:Mixed',
#  'ERS2584890': 'root:Mixed:temperate grassland:soil:Root',
#  'ERS2468541': 'root:Mixed',
#  'ERS1376178': 'root:Mixed',
#  'SRS1846260': 'root:Mixed',
#  'ERS2468542': 'root:Mixed',
#  'ERS1376179': 'root:Mixed',
#  'ERS2585071': 'root:Mixed:temperate grassland:soil:Soil',
#  'SRS1846261': 'root:Mixed',
#  'ERS2585095': 'root:Mixed:temperate grassland:soil:Soil',
#  'ERS1376180': 'root:Mixed',
#  'ERS2468543': 'root:Mixed',
#  'SRS1846262': 'root:Mixed',
#  'ERS2584348': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS1376181': 'root:Mixed',
#  'SRS1846263': 'root:Mixed',
#  'ERS2468544': 'root:Mixed',
#  'ERS2584487': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS1376182': 'root:Mixed',
#  'SRS1846264': 'root:Mixed',
#  'ERS2468545': 'root:Mixed',
#  'ERS2584634': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS1376183': 'root:Mixed',
#  'SRS1846265': 'root:Mixed',
#  'ERS2468546': 'root:Mixed',
#  'ERS2584774': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS1376184': 'root:Mixed',
#  'ERS2468547': 'root:Mixed',
#  'SRS1846266': 'root:Mixed',
#  'ERS1376185': 'root:Mixed',
#  'ERS2468548': 'root:Mixed',
#  'ERS2584891': 'root:Mixed:temperate grassland:soil:Root',
#  'SRS1846267': 'root:Mixed',
#  'ERS1376186': 'root:Mixed',
#  'ERS2468549': 'root:Mixed',
#  'ERS2585072': 'root:Mixed:temperate grassland:soil:Soil',
#  'SRS1846268': 'root:Mixed',
#  'ERS1376187': 'root:Mixed',
#  'ERS2468550': 'root:Mixed',
#  'SRS1846269': 'root:Mixed',
#  'ERS1376188': 'root:Mixed',
#  'ERS2468551': 'root:Mixed',
#  'ERS2584349': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'SRS1846270': 'root:Mixed',
#  'ERS1376189': 'root:Mixed',
#  'ERS2468552': 'root:Mixed',
#  'ERS2584488': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'SRS1846271': 'root:Mixed',
#  'ERS1376190': 'root:Mixed',
#  'ERS2468553': 'root:Mixed',
#  'ERS2584635': 'root:Mixed:temperate grassland:soil:Leaf',
#  'SRS1846272': 'root:Mixed',
#  'ERS1376191': 'root:Mixed',
#  'ERS2468554': 'root:Mixed',
#  'ERS2584775': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS1376192': 'root:Mixed',
#  'SRS1846274': 'root:Mixed',
#  'ERS2468555': 'root:Mixed',
#  'ERS2584892': 'root:Mixed:temperate grassland:soil:Root',
#  'ERS1376193': 'root:Mixed',
#  'SRS1846273': 'root:Mixed',
#  'ERS2468556': 'root:Mixed',
#  'ERS2585073': 'root:Mixed:temperate grassland:soil:Soil',
#  'ERS1376194': 'root:Mixed',
#  'SRS1846275': 'root:Mixed',
#  'ERS2468557': 'root:Mixed',
#  'SRS1846276': 'root:Mixed',
#  'ERS1376195': 'root:Mixed',
#  'ERS2468558': 'root:Mixed',
#  'ERS2584350': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'SRS1846278': 'root:Mixed',
#  'ERS1376196': 'root:Mixed',
#  'ERS2584489': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS2468559': 'root:Mixed',
#  'SRS1846277': 'root:Mixed',
#  'ERS1376197': 'root:Mixed',
#  'ERS2584636': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS2468560': 'root:Mixed',
#  'SRS1846279': 'root:Mixed',
#  'ERS1376198': 'root:Mixed',
#  'ERS2584776': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS2468561': 'root:Mixed',
#  'SRS1846281': 'root:Mixed',
#  'ERS1376199': 'root:Mixed',
#  'ERS2584893': 'root:Mixed:temperate grassland:soil:Root',
#  'ERS2468562': 'root:Mixed',
#  'SRS1846280': 'root:Mixed',
#  'ERS1376200': 'root:Mixed',
#  'ERS2585074': 'root:Mixed:temperate grassland:soil:Soil',
#  'ERS2468563': 'root:Mixed',
#  'SRS1846282': 'root:Mixed',
#  'ERS1376201': 'root:Mixed',
#  'ERS2468564': 'root:Mixed',
#  'ERS2584351': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'SRS1846284': 'root:Mixed',
#  'ERS1376202': 'root:Mixed',
#  'ERS2468565': 'root:Mixed',
#  'ERS2584490': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'SRS1846285': 'root:Mixed',
#  'ERS1376203': 'root:Mixed',
#  'ERS2468566': 'root:Mixed',
#  'ERS2584637': 'root:Mixed:temperate grassland:soil:Leaf',
#  'SRS1846287': 'root:Mixed',
#  'ERS1376204': 'root:Mixed',
#  'SRS1846286': 'root:Mixed',
#  'ERS2468567': 'root:Mixed',
#  'ERS2584777': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS1376205': 'root:Mixed',
#  'SRS1846289': 'root:Mixed',
#  'ERS2468568': 'root:Mixed',
#  'ERS2584894': 'root:Mixed:temperate grassland:soil:Root',
#  'ERS1376206': 'root:Mixed',
#  'SRS1846288': 'root:Mixed',
#  'ERS2468569': 'root:Mixed',
#  'ERS2585075': 'root:Mixed:temperate grassland:soil:Soil',
#  'SRS1846290': 'root:Mixed',
#  'ERS1376207': 'root:Mixed',
#  'ERS2468570': 'root:Mixed',
#  'ERS2585099': 'root:Mixed:temperate grassland:soil:Soil',
#  'ERS1376208': 'root:Mixed',
#  'SRS1846292': 'root:Mixed',
#  'ERS2584352': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS2468571': 'root:Mixed',
#  'SRS1846293': 'root:Mixed',
#  'ERS1376209': 'root:Mixed',
#  'ERS2468572': 'root:Mixed',
#  'ERS2302353': 'root:Mixed:urban biome:animal-associated habitat:organic material',
#  'ERS2302356': 'root:Mixed:urban biome:human-associated habitat:organic material',
#  'ERS2302362': 'root:Mixed:urban biome:animal-associated habitat:organic material',
#  'ERS2302365': 'root:Mixed:urban biome:research facility:sterile water',
#  'ERS2302368': 'root:Mixed:village biome:building:dust',
#  'ERS2302371': 'root:Mixed:village biome:human-associated habitat:sebum',
#  'ERS2302376': 'root:Mixed:village biome:building:dust',
#  'ERS2302379': 'root:Mixed:village biome:building:dust',
#  'ERS2302441': 'root:Mixed:village biome:human-associated habitat:sebum',
#  'ERS2302564': 'root:Mixed:village biome:human-associated habitat:sebum',
#  'ERS2302589': 'root:Mixed:village biome:human-associated habitat:sebum',
#  'ERS2302596': 'root:Mixed:village biome:building:dust',
#  'ERS2302603': 'root:Mixed:village biome:building:dust',
#  'ERS2302611': 'root:Mixed:village biome:building:dust',
#  'ERS2302635': 'root:Mixed:village biome:building:dust',
#  'ERS2302643': 'root:Mixed:village biome:building:dust',
#  'ERS2302651': 'root:Mixed:village biome:building:dust',
#  'ERS2302660': 'root:Mixed:village biome:building:dust',
#  'ERS2302664': 'root:Mixed:village biome:building:dust',
#  'ERS2302671': 'root:Mixed:village biome:building:dust',
#  'ERS2302680': 'root:Mixed:village biome:building:dust',
#  'ERS2302789': 'root:Mixed:urban biome:building:dust',
#  'ERS2302790': 'root:Mixed:urban biome:building:dust',
#  'ERS2302793': 'root:Mixed:urban biome:building:dust',
#  'ERS2302801': 'root:Mixed:urban biome:building:dust',
#  'SRS1846291': 'root:Mixed',
#  'ERS2584491': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS1376210': 'root:Mixed',
#  'ERS2468573': 'root:Mixed',
#  'SRS1846294': 'root:Mixed',
#  'ERS2584638': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS1376211': 'root:Mixed',
#  'ERS2468574': 'root:Mixed',
#  'SRS1846295': 'root:Mixed',
#  'ERS2584778': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS1376212': 'root:Mixed',
#  'ERS2468575': 'root:Mixed',
#  'SRS1846296': 'root:Mixed',
#  'ERS2584895': 'root:Mixed:temperate grassland:soil:Root',
#  'ERS2468576': 'root:Mixed',
#  'ERS1376213': 'root:Mixed',
#  'SRS1846297': 'root:Mixed',
#  'ERS2585076': 'root:Mixed:temperate grassland:soil:Soil',
#  'ERS1376214': 'root:Mixed',
#  'ERS2468577': 'root:Mixed',
#  'SRS1846298': 'root:Mixed',
#  'ERS1376215': 'root:Mixed',
#  'ERS2468578': 'root:Mixed',
#  'ERS2584353': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'SRS1846299': 'root:Mixed',
#  'ERS1376216': 'root:Mixed',
#  'ERS2468579': 'root:Mixed',
#  'SRS1846300': 'root:Mixed',
#  'ERS2584492': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS1376217': 'root:Mixed',
#  'ERS2468580': 'root:Mixed',
#  'SRS1846301': 'root:Mixed',
#  'ERS2584639': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS1376218': 'root:Mixed',
#  'SRS1846302': 'root:Mixed',
#  'ERS2468581': 'root:Mixed',
#  'ERS1376219': 'root:Mixed',
#  'ERS2584779': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS2468582': 'root:Mixed',
#  'ERS1376220': 'root:Mixed',
#  'SRS1846303': 'root:Mixed',
#  'ERS2584896': 'root:Mixed:temperate grassland:soil:Root',
#  'ERS2468583': 'root:Mixed',
#  'SRS1846304': 'root:Mixed',
#  'ERS1376221': 'root:Mixed',
#  'ERS2585077': 'root:Mixed:temperate grassland:soil:Soil',
#  'ERS2468584': 'root:Mixed',
#  'SRS1846305': 'root:Mixed',
#  'ERS1376222': 'root:Mixed',
#  'ERS2468585': 'root:Mixed',
#  'SRS1846306': 'root:Mixed',
#  'ERS1376223': 'root:Mixed',
#  'ERS2584354': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS2468586': 'root:Mixed',
#  'SRS1846307': 'root:Mixed',
#  'ERS2584493': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS1376224': 'root:Mixed',
#  'ERS2584640': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS2468587': 'root:Mixed',
#  'SRS1846308': 'root:Mixed',
#  'ERS1376225': 'root:Mixed',
#  'SRS1846309': 'root:Mixed',
#  'ERS2584780': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS2468588': 'root:Mixed',
#  'ERS1376226': 'root:Mixed',
#  'SRS1846310': 'root:Mixed',
#  'ERS2468589': 'root:Mixed',
#  'ERS2584897': 'root:Mixed:temperate grassland:soil:Root',
#  'ERS1376227': 'root:Mixed',
#  'SRS1846311': 'root:Mixed',
#  'ERS2468590': 'root:Mixed',
#  'ERS2585078': 'root:Mixed:temperate grassland:soil:Soil',
#  'ERS1376228': 'root:Mixed',
#  'ERS2584355': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS2468591': 'root:Mixed',
#  'ERS1376229': 'root:Mixed',
#  'SRS1846312': 'root:Mixed',
#  'ERS2468592': 'root:Mixed',
#  'ERS2584494': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'SRS1846313': 'root:Mixed',
#  'ERS1376230': 'root:Mixed',
#  'ERS2468593': 'root:Mixed',
#  'SRS1846314': 'root:Mixed',
#  'ERS2584641': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS1376231': 'root:Mixed',
#  'ERS2468594': 'root:Mixed',
#  'SRS1846315': 'root:Mixed',
#  'ERS2584781': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS1376232': 'root:Mixed',
#  'ERS2468595': 'root:Mixed',
#  'ERS2584898': 'root:Mixed:temperate grassland:soil:Root',
#  'SRS1846316': 'root:Mixed',
#  'ERS2468596': 'root:Mixed',
#  'ERS1376233': 'root:Mixed',
#  'ERS2585079': 'root:Mixed:temperate grassland:soil:Soil',
#  'SRS1846317': 'root:Mixed',
#  'ERS2468597': 'root:Mixed',
#  'ERS1376234': 'root:Mixed',
#  'ERS2468598': 'root:Mixed',
#  'ERS1376235': 'root:Mixed',
#  'ERS2585102': 'root:Mixed:temperate grassland:soil:Soil',
#  'SRS1846318': 'root:Mixed',
#  'ERS2468599': 'root:Mixed',
#  'ERS2584356': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS1376236': 'root:Mixed',
#  'SRS1846319': 'root:Mixed',
#  'ERS2468600': 'root:Mixed',
#  'ERS2584642': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS1376237': 'root:Mixed',
#  'ERS2468601': 'root:Mixed',
#  'SRS1846320': 'root:Mixed',
#  'ERS2584782': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS1376238': 'root:Mixed',
#  'SRS1846321': 'root:Mixed',
#  'ERS2468602': 'root:Mixed',
#  'ERS2584899': 'root:Mixed:temperate grassland:soil:Root',
#  'ERS1376239': 'root:Mixed',
#  'SRS1846322': 'root:Mixed',
#  'ERS2468603': 'root:Mixed',
#  'ERS1376240': 'root:Mixed',
#  'ERS2585080': 'root:Mixed:temperate grassland:soil:Soil',
#  'SRS1846323': 'root:Mixed',
#  'ERS2468604': 'root:Mixed',
#  'ERS1376241': 'root:Mixed',
#  'SRS1846324': 'root:Mixed',
#  'ERS2468605': 'root:Mixed',
#  'ERS2584357': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS1376242': 'root:Mixed',
#  'SRS1846325': 'root:Mixed',
#  'ERS2584495': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS1376243': 'root:Mixed',
#  'ERS2468606': 'root:Mixed',
#  'SRS1846326': 'root:Mixed',
#  'ERS1376244': 'root:Mixed',
#  'ERS2584643': 'root:Mixed:temperate grassland:soil:Leaf',
#  'SRS1846327': 'root:Mixed',
#  'ERS2468607': 'root:Mixed',
#  'ERS1376245': 'root:Mixed',
#  'ERS2468608': 'root:Mixed',
#  'ERS2584783': 'root:Mixed:temperate grassland:soil:Leaf',
#  'SRS1846328': 'root:Mixed',
#  'ERS1376246': 'root:Mixed',
#  'ERS2584900': 'root:Mixed:temperate grassland:soil:Root',
#  'ERS2468609': 'root:Mixed',
#  'SRS1846329': 'root:Mixed',
#  'ERS1376247': 'root:Mixed',
#  'SRS1846330': 'root:Mixed',
#  'ERS2585081': 'root:Mixed:temperate grassland:soil:Soil',
#  'ERS2468610': 'root:Mixed',
#  'ERS1376248': 'root:Mixed',
#  'SRS1846331': 'root:Mixed',
#  'ERS2585104': 'root:Mixed:temperate grassland:soil:Soil',
#  'ERS2468611': 'root:Mixed',
#  'ERS1376249': 'root:Mixed',
#  'SRS1846332': 'root:Mixed',
#  'ERS2584358': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS2468612': 'root:Mixed',
#  'ERS2584496': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS2468613': 'root:Mixed',
#  'SRS1846333': 'root:Mixed',
#  'ERS1376250': 'root:Mixed',
#  'ERS2584644': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS2468614': 'root:Mixed',
#  'SRS1846334': 'root:Mixed',
#  'ERS2584784': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS1376251': 'root:Mixed',
#  'ERS2468615': 'root:Mixed',
#  'SRS1846335': 'root:Mixed',
#  'ERS2584901': 'root:Mixed:temperate grassland:soil:Root',
#  'ERS2468616': 'root:Mixed',
#  'ERS1376252': 'root:Mixed',
#  'SRS1846336': 'root:Mixed',
#  'ERS2585082': 'root:Mixed:temperate grassland:soil:Soil',
#  'ERS2468617': 'root:Mixed',
#  'ERS1376253': 'root:Mixed',
#  'SRS1846337': 'root:Mixed',
#  'ERS2468618': 'root:Mixed',
#  'ERS1376254': 'root:Mixed',
#  'ERS2584359': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'SRS1846338': 'root:Mixed',
#  'ERS1376255': 'root:Mixed',
#  'ERS2468619': 'root:Mixed',
#  'ERS2584497': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'SRS1846339': 'root:Mixed',
#  'ERS1376256': 'root:Mixed',
#  'ERS2468620': 'root:Mixed',
#  'ERS2584645': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS1376257': 'root:Mixed',
#  'SRS1846340': 'root:Mixed',
#  'ERS2468621': 'root:Mixed',
#  'ERS1376258': 'root:Mixed',
#  'ERS2584785': 'root:Mixed:temperate grassland:soil:Leaf',
#  'SRS1846341': 'root:Mixed',
#  'ERS2468622': 'root:Mixed',
#  'ERS2585083': 'root:Mixed:temperate grassland:soil:Soil',
#  'ERS1376259': 'root:Mixed',
#  'SRS1846342': 'root:Mixed',
#  'ERS2468623': 'root:Mixed',
#  'ERS2585106': 'root:Mixed:temperate grassland:soil:Soil',
#  'ERS1376260': 'root:Mixed',
#  'ERS2468624': 'root:Mixed',
#  'SRS1846343': 'root:Mixed',
#  'ERS1376261': 'root:Mixed',
#  'ERS2584360': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS2468625': 'root:Mixed',
#  'SRS1846344': 'root:Mixed',
#  'ERS1376262': 'root:Mixed',
#  'ERS2584498': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS2468626': 'root:Mixed',
#  'SRS1846345': 'root:Mixed',
#  'ERS2584646': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS1376263': 'root:Mixed',
#  'SRS1846346': 'root:Mixed',
#  'ERS2468627': 'root:Mixed',
#  'ERS1376264': 'root:Mixed',
#  'ERS2584786': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS2468628': 'root:Mixed',
#  'SRS1846347': 'root:Mixed',
#  'ERS1376265': 'root:Mixed',
#  'ERS2584902': 'root:Mixed:temperate grassland:soil:Root',
#  'SRS1846348': 'root:Mixed',
#  'ERS2468629': 'root:Mixed',
#  'ERS1376266': 'root:Mixed',
#  'ERS2585107': 'root:Mixed:temperate grassland:soil:Soil',
#  'ERS2468630': 'root:Mixed',
#  'SRS1846349': 'root:Mixed',
#  'ERS1376267': 'root:Mixed',
#  'ERS2468631': 'root:Mixed',
#  'ERS2584361': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS1376268': 'root:Mixed',
#  'SRS1846350': 'root:Mixed',
#  'ERS2468632': 'root:Mixed',
#  'ERS2584499': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS2584647': 'root:Mixed:temperate grassland:soil:Leaf',
#  'SRS1846351': 'root:Mixed',
#  'ERS1376269': 'root:Mixed',
#  'ERS2468633': 'root:Mixed',
#  'ERS2584787': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS1376270': 'root:Mixed',
#  'SRS1846352': 'root:Mixed',
#  'ERS2468634': 'root:Mixed',
#  'ERS1376271': 'root:Mixed',
#  'ERS2584903': 'root:Mixed:temperate grassland:soil:Root',
#  'SRS1846353': 'root:Mixed',
#  'ERS2468635': 'root:Mixed',
#  'ERS1376272': 'root:Mixed',
#  'ERS2585084': 'root:Mixed:temperate grassland:soil:Soil',
#  'SRS1846354': 'root:Mixed',
#  'ERS1376273': 'root:Mixed',
#  'ERS2584362': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS2302805': 'root:Mixed:urban biome:building:dust',
#  'ERS2302809': 'root:Mixed:urban biome:building:dust',
#  'ERS2302814': 'root:Mixed:urban biome:building:dust',
#  'ERS2302818': 'root:Mixed:urban biome:building:dust',
#  'ERS2302823': 'root:Mixed:urban biome:building:dust',
#  'ERS2302827': 'root:Mixed:urban biome:building:dust',
#  'ERS2302837': 'root:Mixed:urban biome:building:dust',
#  'ERS2302843': 'root:Mixed:urban biome:building:dust',
#  'ERS2302847': 'root:Mixed:urban biome:building:dust',
#  'ERS2302853': 'root:Mixed:urban biome:building:dust',
#  'ERS2302857': 'root:Mixed:urban biome:building:dust',
#  'ERS2302863': 'root:Mixed:urban biome:building:dust',
#  'ERS2302887': 'root:Mixed:village biome:human-associated habitat:sebum',
#  'ERS2302898': 'root:Mixed:village biome:building:dust',
#  'ERS2302903': 'root:Mixed:village biome:building:dust',
#  'ERS2302912': 'root:Mixed:village biome:human-associated habitat:sebum',
#  'ERS2302923': 'root:Mixed:village biome:building:dust',
#  'ERS2303016': 'root:Mixed:village biome:building:dust',
#  'ERS2303022': 'root:Mixed:village biome:building:dust',
#  'ERS2303027': 'root:Mixed:village biome:human-associated habitat:sebum',
#  'ERS2303032': 'root:Mixed:village biome:human-associated habitat:sebum',
#  'ERS2303037': 'root:Mixed:village biome:building:dust',
#  'ERS2303040': 'root:Mixed:urban biome:human-associated habitat:sebum',
#  'ERS2303043': 'root:Mixed:village biome:building:dust',
#  'ERS2303048': 'root:Mixed:village biome:human-associated habitat:sebum',
#  'ERS2468636': 'root:Mixed',
#  'ERS1376274': 'root:Mixed',
#  'SRS1846355': 'root:Mixed',
#  'ERS2584500': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS2468637': 'root:Mixed',
#  'ERS1376275': 'root:Mixed',
#  'SRS1846356': 'root:Mixed',
#  'ERS2468638': 'root:Mixed',
#  'ERS2584648': 'root:Mixed:temperate grassland:soil:Leaf',
#  'SRS1846357': 'root:Mixed',
#  'ERS2468639': 'root:Mixed',
#  'ERS1376276': 'root:Mixed',
#  'ERS2584788': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS1376277': 'root:Mixed',
#  'ERS2584904': 'root:Mixed:temperate grassland:soil:Root',
#  'ERS2468640': 'root:Mixed',
#  'SRS1846358': 'root:Mixed',
#  'ERS2468641': 'root:Mixed',
#  'ERS2585108': 'root:Mixed:temperate grassland:soil:Soil',
#  'ERS1376278': 'root:Mixed',
#  'SRS1846359': 'root:Mixed',
#  'ERS2584501': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS1376279': 'root:Mixed',
#  'ERS2468642': 'root:Mixed',
#  'SRS1846360': 'root:Mixed',
#  'ERS2584649': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS1376280': 'root:Mixed',
#  'SRS1846361': 'root:Mixed',
#  'ERS2468643': 'root:Mixed',
#  'ERS2584789': 'root:Mixed:temperate grassland:soil:Leaf',
#  'SRS1846362': 'root:Mixed',
#  'ERS2468644': 'root:Mixed',
#  'ERS1376281': 'root:Mixed',
#  'ERS2584905': 'root:Mixed:temperate grassland:soil:Root',
#  'ERS2468645': 'root:Mixed',
#  'SRS1846363': 'root:Mixed',
#  'ERS1376282': 'root:Mixed',
#  'SRS1846364': 'root:Mixed',
#  'ERS2468646': 'root:Mixed',
#  'ERS1376283': 'root:Mixed',
#  'ERS2584502': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'SRS1846365': 'root:Mixed',
#  'ERS2468647': 'root:Mixed',
#  'ERS1376284': 'root:Mixed',
#  'ERS2584650': 'root:Mixed:temperate grassland:soil:Leaf',
#  'SRS1846367': 'root:Mixed',
#  'ERS1376285': 'root:Mixed',
#  'ERS2468648': 'root:Mixed',
#  'ERS2584790': 'root:Mixed:temperate grassland:soil:Leaf',
#  'SRS1846366': 'root:Mixed',
#  'ERS1376286': 'root:Mixed',
#  'ERS2468649': 'root:Mixed',
#  'ERS2584906': 'root:Mixed:temperate grassland:soil:Root',
#  'ERS1376287': 'root:Mixed',
#  'SRS1846368': 'root:Mixed',
#  'ERS2468650': 'root:Mixed',
#  'SRS1846369': 'root:Mixed',
#  'ERS1376288': 'root:Mixed',
#  'ERS2468651': 'root:Mixed',
#  'ERS2584363': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS1376289': 'root:Mixed',
#  'SRS1846370': 'root:Mixed',
#  'ERS2468652': 'root:Mixed',
#  'ERS2584503': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS1376290': 'root:Mixed',
#  'SRS1846371': 'root:Mixed',
#  'ERS2468653': 'root:Mixed',
#  'ERS2584651': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS1376291': 'root:Mixed',
#  'SRS1846372': 'root:Mixed',
#  'ERS2468654': 'root:Mixed',
#  'ERS2584791': 'root:Mixed:temperate grassland:soil:Leaf',
#  'SRS1846373': 'root:Mixed',
#  'ERS1376292': 'root:Mixed',
#  'ERS2468655': 'root:Mixed',
#  'ERS2584907': 'root:Mixed:temperate grassland:soil:Root',
#  'SRS1846376': 'root:Mixed',
#  'ERS1376293': 'root:Mixed',
#  'ERS2468656': 'root:Mixed',
#  'SRS1846377': 'root:Mixed',
#  'ERS1376294': 'root:Mixed',
#  'ERS2468657': 'root:Mixed',
#  'ERS2584364': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS1376295': 'root:Mixed',
#  'SRS1846378': 'root:Mixed',
#  'ERS2468658': 'root:Mixed',
#  'ERS2584504': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS1376296': 'root:Mixed',
#  'SRS1846379': 'root:Mixed',
#  'ERS2468659': 'root:Mixed',
#  'ERS2584652': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS1376297': 'root:Mixed',
#  'SRS1846380': 'root:Mixed',
#  'ERS2468660': 'root:Mixed',
#  'ERS2584792': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS1376298': 'root:Mixed',
#  'SRS1846381': 'root:Mixed',
#  'ERS2468661': 'root:Mixed',
#  'ERS2584908': 'root:Mixed:temperate grassland:soil:Root',
#  'SRS1846382': 'root:Mixed',
#  'ERS1376299': 'root:Mixed',
#  'ERS2468662': 'root:Mixed',
#  'ERS1376300': 'root:Mixed',
#  'ERS2468663': 'root:Mixed',
#  'SRS1846383': 'root:Mixed',
#  'ERS2584365': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS1376301': 'root:Mixed',
#  'ERS2584505': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'SRS1846384': 'root:Mixed',
#  'ERS2468664': 'root:Mixed',
#  'ERS1376302': 'root:Mixed',
#  'ERS2584653': 'root:Mixed:temperate grassland:soil:Leaf',
#  'SRS1846385': 'root:Mixed',
#  'ERS2468665': 'root:Mixed',
#  'SRS1846386': 'root:Mixed',
#  'ERS2584793': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS1376303': 'root:Mixed',
#  'ERS2468666': 'root:Mixed',
#  'SRS1846388': 'root:Mixed',
#  'ERS1376304': 'root:Mixed',
#  'ERS2468667': 'root:Mixed',
#  'ERS2584909': 'root:Mixed:temperate grassland:soil:Root',
#  'SRS1846389': 'root:Mixed',
#  'ERS1376305': 'root:Mixed',
#  'ERS2468668': 'root:Mixed',
#  'ERS2585113': 'root:Mixed:temperate grassland:soil:Soil',
#  'SRS1846390': 'root:Mixed',
#  'ERS1376306': 'root:Mixed',
#  'ERS2468669': 'root:Mixed',
#  'ERS2584366': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'SRS1846391': 'root:Mixed',
#  'ERS1376307': 'root:Mixed',
#  'ERS2468670': 'root:Mixed',
#  'ERS2584506': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'SRS1846392': 'root:Mixed',
#  'ERS1376308': 'root:Mixed',
#  'ERS2584654': 'root:Mixed:temperate grassland:soil:Leaf',
#  'SRS1846393': 'root:Mixed',
#  'ERS1376309': 'root:Mixed',
#  'SRS1846394': 'root:Mixed',
#  'ERS2584794': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS2468672': 'root:Mixed',
#  'ERS1376310': 'root:Mixed',
#  'SRS1846395': 'root:Mixed',
#  'ERS2584910': 'root:Mixed:temperate grassland:soil:Root',
#  'ERS2468673': 'root:Mixed',
#  'ERS1376311': 'root:Mixed',
#  'SRS1846396': 'root:Mixed',
#  'ERS2468674': 'root:Mixed',
#  'SRS1846397': 'root:Mixed',
#  'ERS1376312': 'root:Mixed',
#  'ERS2584367': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS2468675': 'root:Mixed',
#  'ERS1376313': 'root:Mixed',
#  'SRS1846398': 'root:Mixed',
#  'ERS2468676': 'root:Mixed',
#  'ERS2584507': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS2584655': 'root:Mixed:temperate grassland:soil:Leaf',
#  'SRS1846399': 'root:Mixed',
#  'ERS1376314': 'root:Mixed',
#  'ERS2468677': 'root:Mixed',
#  'ERS2584795': 'root:Mixed:temperate grassland:soil:Leaf',
#  'SRS1846400': 'root:Mixed',
#  'ERS2468678': 'root:Mixed',
#  'ERS1376315': 'root:Mixed',
#  'ERS2584911': 'root:Mixed:temperate grassland:soil:Root',
#  'SRS1846401': 'root:Mixed',
#  'ERS2468679': 'root:Mixed',
#  'ERS1376316': 'root:Mixed',
#  'SRS1846402': 'root:Mixed',
#  'ERS1376317': 'root:Mixed',
#  'ERS2468680': 'root:Mixed',
#  'ERS2584508': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS1376318': 'root:Mixed',
#  'SRS1846403': 'root:Mixed',
#  'ERS2468681': 'root:Mixed',
#  'ERS2584656': 'root:Mixed:temperate grassland:soil:Leaf',
#  'SRS1846404': 'root:Mixed',
#  'ERS1376319': 'root:Mixed',
#  'ERS2468682': 'root:Mixed',
#  'ERS1376320': 'root:Mixed',
#  'ERS2468683': 'root:Mixed',
#  'SRS1846405': 'root:Mixed',
#  'ERS2584796': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS1376321': 'root:Mixed',
#  'ERS2468684': 'root:Mixed',
#  'SRS1846406': 'root:Mixed',
#  'ERS2584912': 'root:Mixed:temperate grassland:soil:Root',
#  'ERS1376322': 'root:Mixed',
#  'SRS1846407': 'root:Mixed',
#  'ERS2468685': 'root:Mixed',
#  'ERS2585116': 'root:Mixed:temperate grassland:soil:Soil',
#  'ERS1376323': 'root:Mixed',
#  'SRS1846408': 'root:Mixed',
#  'ERS2468686': 'root:Mixed',
#  'ERS2584368': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS2468687': 'root:Mixed',
#  'ERS1376324': 'root:Mixed',
#  'SRS1846409': 'root:Mixed',
#  'ERS2584509': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS2468688': 'root:Mixed',
#  'SRS1846410': 'root:Mixed',
#  'ERS1376325': 'root:Mixed',
#  'ERS2584657': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS2468689': 'root:Mixed',
#  'ERS1376326': 'root:Mixed',
#  'SRS1846411': 'root:Mixed',
#  'ERS2584797': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS2468690': 'root:Mixed',
#  'ERS1376327': 'root:Mixed',
#  'SRS1846412': 'root:Mixed',
#  'ERS2468691': 'root:Mixed',
#  'ERS1376328': 'root:Mixed',
#  'SRS1846413': 'root:Mixed',
#  'ERS2584913': 'root:Mixed:temperate grassland:soil:Root',
#  'ERS2468692': 'root:Mixed',
#  'ERS1376329': 'root:Mixed',
#  'SRS1846414': 'root:Mixed',
#  'ERS2468693': 'root:Mixed',
#  'ERS1376330': 'root:Mixed',
#  'SRS1846415': 'root:Mixed',
#  'ERS2584369': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS2468694': 'root:Mixed',
#  'ERS1376331': 'root:Mixed',
#  'SRS1846416': 'root:Mixed',
#  'ERS2468695': 'root:Mixed',
#  'ERS2584510': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS1376332': 'root:Mixed',
#  'ERS2468696': 'root:Mixed',
#  'ERS2584658': 'root:Mixed:temperate grassland:soil:Leaf',
#  'SRS1846418': 'root:Mixed',
#  'ERS2584798': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS2468697': 'root:Mixed',
#  'ERS1376333': 'root:Mixed',
#  'ERS2584914': 'root:Mixed:temperate grassland:soil:Root',
#  'ERS2468698': 'root:Mixed',
#  'ERS1376334': 'root:Mixed',
#  'SRS1846419': 'root:Mixed',
#  'ERS2468699': 'root:Mixed',
#  'ERS2585118': 'root:Mixed:temperate grassland:soil:Soil',
#  'SRS1846420': 'root:Mixed',
#  'ERS1376335': 'root:Mixed',
#  'ERS2468700': 'root:Mixed',
#  'ERS1376336': 'root:Mixed',
#  'ERS2584511': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS2584659': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS2468702': 'root:Mixed',
#  'ERS1376338': 'root:Mixed',
#  'ERS2584799': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS2468703': 'root:Mixed',
#  'ERS2303054': 'root:Mixed:urban biome:research facility:sterile water',
#  'ERS2303059': 'root:Mixed:urban biome:research facility:sterile water',
#  'ERS2303066': 'root:Mixed:urban biome:research facility:sterile water',
#  'ERS2303738': 'root:Mixed:urban biome:research facility:sterile water',
#  'ERS2303745': 'root:Mixed:urban biome:research facility:sterile water',
#  'ERS2303757': 'root:Mixed:urban biome:research facility:sterile water',
#  'ERS2303769': 'root:Mixed:urban biome:research facility:sterile water',
#  'ERS2303781': 'root:Mixed:urban biome:research facility:sterile water',
#  'ERS2303786': 'root:Mixed:urban biome:research facility:sterile water',
#  'ERS2303793': 'root:Mixed:urban biome:research facility:sterile water',
#  'ERS2303811': 'root:Mixed:urban biome:research facility:sterile water',
#  'ERS2303818': 'root:Mixed:urban biome:research facility:sterile water',
#  'ERS2301544': 'root:Mixed:village biome:human-associated habitat:sebum',
#  'ERS2302380': 'root:Mixed:village biome:building:dust',
#  'ERS2301554': 'root:Mixed:village biome:human-associated habitat:sebum',
#  'ERS2302400': 'root:Mixed:village biome:building:dust',
#  'ERS2302464': 'root:Mixed:village biome:building:dust',
#  'ERS2302469': 'root:Mixed:village biome:building:dust',
#  'ERS2301639': 'root:Mixed:village biome:human-associated habitat:sebum',
#  'ERS2301648': 'root:Mixed:village biome:human-associated habitat:sebum',
#  'ERS2301661': 'root:Mixed:village biome:human-associated habitat:sebum',
#  'ERS2301666': 'root:Mixed:village biome:human-associated habitat:sebum',
#  'ERS2302525': 'root:Mixed:village biome:building:dust',
#  'ERS2301707': 'root:Mixed:village biome:human-associated habitat:sebum',
#  'ERS2302552': 'root:Mixed:village biome:building:dust',
#  'SRS1846424': 'root:Mixed',
#  'ERS1376339': 'root:Mixed',
#  'ERS2584915': 'root:Mixed:temperate grassland:soil:Root',
#  'SRS1846425': 'root:Mixed',
#  'ERS2468704': 'root:Mixed',
#  'ERS1376340': 'root:Mixed',
#  'SRS1846426': 'root:Mixed',
#  'ERS1376341': 'root:Mixed',
#  'ERS2468705': 'root:Mixed',
#  'ERS2584371': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'SRS1846427': 'root:Mixed',
#  'ERS2468706': 'root:Mixed',
#  'ERS1376342': 'root:Mixed',
#  'ERS2584512': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'SRS1846428': 'root:Mixed',
#  'ERS2468707': 'root:Mixed',
#  'ERS1376343': 'root:Mixed',
#  'ERS2584660': 'root:Mixed:temperate grassland:soil:Leaf',
#  'SRS1846429': 'root:Mixed',
#  'ERS1376344': 'root:Mixed',
#  'ERS2468708': 'root:Mixed',
#  'ERS2584800': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS1376345': 'root:Mixed',
#  'SRS1846430': 'root:Mixed',
#  'ERS2468709': 'root:Mixed',
#  'ERS2584916': 'root:Mixed:temperate grassland:soil:Root',
#  'ERS1376346': 'root:Mixed',
#  'SRS1846431': 'root:Mixed',
#  'ERS2468710': 'root:Mixed',
#  'SRS1846432': 'root:Mixed',
#  'ERS2468711': 'root:Mixed',
#  'ERS1376347': 'root:Mixed',
#  'ERS2584372': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'SRS1846433': 'root:Mixed',
#  'ERS2468712': 'root:Mixed',
#  'ERS1376348': 'root:Mixed',
#  'ERS2584513': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'SRS1846434': 'root:Mixed',
#  'ERS2468713': 'root:Mixed',
#  'ERS1376349': 'root:Mixed',
#  'ERS2584661': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS1376350': 'root:Mixed',
#  'SRS1846435': 'root:Mixed',
#  'ERS2468714': 'root:Mixed',
#  'ERS2584801': 'root:Mixed:temperate grassland:soil:Leaf',
#  'SRS1846436': 'root:Mixed',
#  'ERS1376351': 'root:Mixed',
#  'ERS2468715': 'root:Mixed',
#  'ERS2584917': 'root:Mixed:temperate grassland:soil:Root',
#  'SRS1846437': 'root:Mixed',
#  'ERS1376352': 'root:Mixed',
#  'ERS2468716': 'root:Mixed',
#  'ERS2585085': 'root:Mixed:temperate grassland:soil:Soil',
#  'SRS1846438': 'root:Mixed',
#  'ERS1376353': 'root:Mixed',
#  'ERS2468717': 'root:Mixed',
#  'SRS1846439': 'root:Mixed',
#  'ERS2468718': 'root:Mixed',
#  'ERS1376354': 'root:Mixed',
#  'ERS2584373': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'SRS1846440': 'root:Mixed',
#  'ERS2468719': 'root:Mixed',
#  'ERS1376355': 'root:Mixed',
#  'ERS2584514': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'SRS1846441': 'root:Mixed',
#  'ERS2468720': 'root:Mixed',
#  'ERS1376356': 'root:Mixed',
#  'ERS2584662': 'root:Mixed:temperate grassland:soil:Leaf',
#  'SRS1846443': 'root:Mixed',
#  'ERS2468721': 'root:Mixed',
#  'ERS1376357': 'root:Mixed',
#  'SRS1846442': 'root:Mixed',
#  'ERS2584802': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS2468722': 'root:Mixed',
#  'ERS1376358': 'root:Mixed',
#  'ERS2584918': 'root:Mixed:temperate grassland:soil:Root',
#  'SRS1846444': 'root:Mixed',
#  'ERS2468723': 'root:Mixed',
#  'ERS1376359': 'root:Mixed',
#  'ERS2585122': 'root:Mixed:temperate grassland:soil:Soil',
#  'ERS2468724': 'root:Mixed',
#  'SRS1846446': 'root:Mixed',
#  'ERS1376360': 'root:Mixed',
#  'ERS2584374': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS2468725': 'root:Mixed',
#  'SRS1846445': 'root:Mixed',
#  'ERS1376361': 'root:Mixed',
#  'ERS2584515': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS2468726': 'root:Mixed',
#  'SRS1846449': 'root:Mixed',
#  'ERS1376362': 'root:Mixed',
#  'ERS2584803': 'root:Mixed:temperate grassland:soil:Leaf',
#  'SRS1846448': 'root:Mixed',
#  'ERS2468727': 'root:Mixed',
#  'ERS2584919': 'root:Mixed:temperate grassland:soil:Root',
#  'ERS1376363': 'root:Mixed',
#  'ERS2468728': 'root:Mixed',
#  'SRS1846447': 'root:Mixed',
#  'ERS1376364': 'root:Mixed',
#  'ERS2468729': 'root:Mixed',
#  'SRS1846451': 'root:Mixed',
#  'ERS2584375': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS1376365': 'root:Mixed',
#  'ERS2468730': 'root:Mixed',
#  'SRS1846452': 'root:Mixed',
#  'ERS2584663': 'root:Mixed:temperate grassland:soil:Leaf',
#  'ERS1376366': 'root:Mixed',
#  'ERS2468731': 'root:Mixed',
#  'SRS1846453': 'root:Mixed',
#  'ERS2584920': 'root:Mixed:temperate grassland:soil:Root',
#  'ERS1376367': 'root:Mixed',
#  'ERS2468732': 'root:Mixed',
#  'ERS2585124': 'root:Mixed:temperate grassland:soil:Soil',
#  'SRS1846455': 'root:Mixed',
#  'ERS1376368': 'root:Mixed',
#  'ERS2468733': 'root:Mixed',
#  'ERS2584376': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'SRS1846454': 'root:Mixed',
#  'ERS1376369': 'root:Mixed',
#  'ERS2468734': 'root:Mixed',
#  'ERS2584516': 'root:Mixed:temperate grassland:soil:Caterpillar',
#  'ERS1376370': 'root:Mixed',
#  'SRS1846456': 'root:Mixed',
#  'ERS2468735': 'root:Mixed',
#  'ERS2584664': 'root:Mixed:temperate grassland:soil:Leaf',
#  ...}

# %%
## extract all samples with biome 'root:Mixed'
df_mixed_biome = df[df['biome'] == 'root:Mixed']
df_mixed_biome
# Out:
#                id      study_id   sample_id       biome      exptype version  \
# 23065  ERR3572850  MGYS00005495  ERS3792294  root:Mixed  metagenomic     4.1
# 23066  ERR3572860  MGYS00005495  ERS3792294  root:Mixed  metagenomic     4.1
# 23067  ERR3572870  MGYS00005495  ERS3792294  root:Mixed  metagenomic     4.1
# 23068  ERR3572880  MGYS00005495  ERS3792294  root:Mixed  metagenomic     4.1
# 23069  ERR3572900  MGYS00005495  ERS3792294  root:Mixed  metagenomic     4.1
# ...           ...           ...         ...         ...          ...     ...
# 25054  ERR3574889  MGYS00005495  ERS3792294  root:Mixed  metagenomic     4.1
# 25055  ERR3574899  MGYS00005495  ERS3792294  root:Mixed  metagenomic     4.1
# 25056  ERR3574909  MGYS00005495  ERS3792294  root:Mixed  metagenomic     4.1
# 25057  ERR3574919  MGYS00005495  ERS3792294  root:Mixed  metagenomic     4.1
# 57608   ERZ483237  MGYS00005519   ERS693376  root:Mixed     assembly     4.1
#
#        GO:0043130  GO:0055074  GO:0055117  GO:0046933  ...  GO:0019357  \
# 23065          49           0           0        3678  ...           0
# 23066          38           0           0        2647  ...           0
# 23067          63           0           0        3199  ...           0
# 23068          46           0           0        2676  ...           0
# 23069          38           0           0        3206  ...           0
# ...           ...         ...         ...         ...  ...         ...
# 25054           0           0           0        1815  ...           0
# 25055           0           0           0        2080  ...           0
# 25056           0           0           0        1357  ...           0
# 25057           1           0           0        1411  ...           0
# 57608           0           0           0          27  ...           2
#
#        GO:0006527  GO:0004114  GO:0046423  GO:0034194  GO:0032183  GO:0007618  \
# 23065         820          24           0         223           0           0
# 23066         615          39           0         135           0           0
# 23067         726          80           0         243           0           0
# 23068         570         144           0         183           0           0
# 23069         712          30           0         266           0           0
# ...           ...         ...         ...         ...         ...         ...
# 25054         321          10           0           3           0           0
# 25055         363           9           0           5           0           0
# 25056         170           5           0          30           0           0
# 25057         147           4           0          22           0           0
# 57608          13           0           0           0           0           0
#
#        GO:0030097  GO:0004520  GO:0033739
# 23065           0        1275         454
# 23066           0         964         359
# 23067           0        1097         424
# 23068           0         894         347
# 23069           0        1097         424
# ...           ...         ...         ...
# 25054           0         695         326
# 25055           0         729         382
# 25056           0        1074          62
# 25057           0        1076          45
# 57608           0          15           0
#
# [1994 rows x 4408 columns]

# %%
## update targeted biomes in origianl dataset
for i, row in df_mixed_biome.iterrows():
    if row['sample_id'] in mixed_label_dic:
        df.loc[i, 'biome'] = mixed_label_dic[row['sample_id']]
df
# Out:
#                id      study_id   sample_id  \
# 19      ERZ650344  MGYS00003358  SRS3210273
# 27      ERZ747221  MGYS00004737  SRS1791943
# 29      ERZ761615  MGYS00003390  SRS1984850
# 30     ERR2193276  MGYS00005065  ERS2001073
# 31     ERR2193277  MGYS00005065  ERS2001074
# ...           ...           ...         ...
# 73785   ERZ807429  MGYS00005443  ERS1960449
# 74255   ERZ795020  MGYS00004901   SRS785549
# 74256   ERZ505245  MGYS00003223  SRS1589217
# 74261   ERZ505291  MGYS00003237  SRS1589396
# 74262   ERZ777305  MGYS00004754   DRS013068
#
#                                                   biome      exptype version  \
# 19           root:Environmental:Aquatic:Marine:Brackish     assembly     4.1
# 27                         root:Engineered:Biogas plant     assembly     4.1
# 29                           root:Engineered:Bioreactor     assembly     4.1
# 30                         root:Host-associated:Mammals  metagenomic     4.1
# 31                         root:Host-associated:Mammals  metagenomic     4.1
# ...                                                 ...          ...     ...
# 73785  root:Host-associated:Human:Digestive system:Oral     assembly     4.1
# 74255                        root:Engineered:Wastewater     assembly     4.1
# 74256                 root:Environmental:Aquatic:Marine     assembly     4.1
# 74261                 root:Environmental:Aquatic:Marine     assembly     4.1
# 74262   root:Host-associated:Mammals:Respiratory system     assembly     4.1
#
#        GO:0043130  GO:0055074  GO:0055117  GO:0046933  ...  GO:0019357  \
# 19              3           0           0         342  ...           2
# 27             49           0           0         450  ...           2
# 29              2           0           0         270  ...          33
# 30              0           0           0          26  ...           0
# 31              0           0           0          31  ...           0
# ...           ...         ...         ...         ...  ...         ...
# 73785           0           0           0           3  ...           0
# 74255           0           0           0         115  ...           1
# 74256           1           0           0         336  ...           3
# 74261           2           0           0         299  ...           2
# 74262           0           0           0         323  ...          21
#
#        GO:0006527  GO:0004114  GO:0046423  GO:0034194  GO:0032183  GO:0007618  \
# 19             79          90           0          20           0           0
# 27            110           0           0          15           0           0
# 29            102           2           0          43           0           0
# 30             12           1           0          15           0           0
# 31             13           1           0          20           0           0
# ...           ...         ...         ...         ...         ...         ...
# 73785           0           0           0           0           0           0
# 74255          10           0           0           1           0           0
# 74256          54           1           0           7           0           0
# 74261          58           0           0          11           0           0
# 74262          41           1           0           0           0           0
#
#        GO:0030097  GO:0004520  GO:0033739
# 19              0          87          38
# 27              0         204          34
# 29              0          93          49
# 30              0           8           5
# 31              0          10           8
# ...           ...         ...         ...
# 73785           0           0           1
# 74255           0          41           8
# 74256           0          88          56
# 74261           0          74          53
# 74262           0         107          39
#
# [31939 rows x 4408 columns]

# %%
## extract samples whose biome is bot 'root:Mixed'
df_ = df[df['biome']!='root:Mixed']

# %%
## save them to files
df_.to_csv(output_file_tsv, sep = '\t')
df_.to_pickle(output_file_pickle)

# %%
df_
# Out:
#                id      study_id   sample_id  \
# 19      ERZ650344  MGYS00003358  SRS3210273
# 27      ERZ747221  MGYS00004737  SRS1791943
# 29      ERZ761615  MGYS00003390  SRS1984850
# 30     ERR2193276  MGYS00005065  ERS2001073
# 31     ERR2193277  MGYS00005065  ERS2001074
# ...           ...           ...         ...
# 73785   ERZ807429  MGYS00005443  ERS1960449
# 74255   ERZ795020  MGYS00004901   SRS785549
# 74256   ERZ505245  MGYS00003223  SRS1589217
# 74261   ERZ505291  MGYS00003237  SRS1589396
# 74262   ERZ777305  MGYS00004754   DRS013068
#
#                                                   biome      exptype version  \
# 19           root:Environmental:Aquatic:Marine:Brackish     assembly     4.1
# 27                         root:Engineered:Biogas plant     assembly     4.1
# 29                           root:Engineered:Bioreactor     assembly     4.1
# 30                         root:Host-associated:Mammals  metagenomic     4.1
# 31                         root:Host-associated:Mammals  metagenomic     4.1
# ...                                                 ...          ...     ...
# 73785  root:Host-associated:Human:Digestive system:Oral     assembly     4.1
# 74255                        root:Engineered:Wastewater     assembly     4.1
# 74256                 root:Environmental:Aquatic:Marine     assembly     4.1
# 74261                 root:Environmental:Aquatic:Marine     assembly     4.1
# 74262   root:Host-associated:Mammals:Respiratory system     assembly     4.1
#
#        GO:0043130  GO:0055074  GO:0055117  GO:0046933  ...  GO:0019357  \
# 19              3           0           0         342  ...           2
# 27             49           0           0         450  ...           2
# 29              2           0           0         270  ...          33
# 30              0           0           0          26  ...           0
# 31              0           0           0          31  ...           0
# ...           ...         ...         ...         ...  ...         ...
# 73785           0           0           0           3  ...           0
# 74255           0           0           0         115  ...           1
# 74256           1           0           0         336  ...           3
# 74261           2           0           0         299  ...           2
# 74262           0           0           0         323  ...          21
#
#        GO:0006527  GO:0004114  GO:0046423  GO:0034194  GO:0032183  GO:0007618  \
# 19             79          90           0          20           0           0
# 27            110           0           0          15           0           0
# 29            102           2           0          43           0           0
# 30             12           1           0          15           0           0
# 31             13           1           0          20           0           0
# ...           ...         ...         ...         ...         ...         ...
# 73785           0           0           0           0           0           0
# 74255          10           0           0           1           0           0
# 74256          54           1           0           7           0           0
# 74261          58           0           0          11           0           0
# 74262          41           1           0           0           0           0
#
#        GO:0030097  GO:0004520  GO:0033739
# 19              0          87          38
# 27              0         204          34
# 29              0          93          49
# 30              0           8           5
# 31              0          10           8
# ...           ...         ...         ...
# 73785           0           0           1
# 74255           0          41           8
# 74256           0          88          56
# 74261           0          74          53
# 74262           0         107          39
#
# [31939 rows x 4408 columns]
